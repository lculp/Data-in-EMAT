# %% [markdown]
# # Lana's Spotify API Data Report
# My hypothesis is that the placement of a track in an album correlates to its popularity.
# #### Theoretically:
# For pop music, if the track is higher up in the album, it is more popular.
# #### Statistically:
# I will test this hypothesis by taking the most popular songs of some of the top 5 pop artists' releases and then compare the track numbers of the most popular songs.
# #### Spotify API Endpoints
# 1. Popularity (the higher the number and closer to 100, the more popular the song is)
# 2. Track Number (hopefully, the higher up on the album the song is and closer to being track number 1, the more popular the song is)
# #### Reliability:
# This data should hopefully be reliable since I am drawing data from the top 5 pop artists rather than just 1 artist. However, doing multiple artists could make the data unreliable due to the artists having different styles, so maybe the endpoints that affect one artist's popularity are different from the other artists.
# #### Limitations
# The fact that I am looking into various different artists may result in more limitations since each artist might not rely on the same endpoints that affect the popularity of a song.

# %%
import urllib
import requests
import pandas as pd 
import json
import base64

# %%
def get_session_token(SessionID, SessionKey):
    url = 'https://accounts.spotify.com/api/token'
    data = {'grant_type':'client_credentials'}
    encoded_key = base64.b64encode(str(SessionID + ":" + SessionKey).\
                                  encode("ascii"))
    header = {'Authorization':'Basic {}'.format(encoded_key.decode("ascii"))}
    response = requests.post(url, 
                            data = data, 
                            headers = header)
    print(response.status_code)
    return response.json()['access_token']

# %%
keys = pd.read_csv("text_files_SpotifyAPI.txt")

# %%
#keys

# %%
access_token = get_session_token(keys['Client_ID'].iloc[0], keys['Client_Secret'].iloc[0])
# Out:
# 200

# %%
t_features_ep = 'https://api.spotify.com/v1/audio-features'
tracks_ep = 'https://api.spotify.com/v1/tracks'
ab_tracks_ep = 'https://api.spotify.com/v1/albums/{}/tracks'

# %%
def api_call(endpoint_url, api_header):
    response = requests.get(endpoint_url, headers = api_header)
    print(response.status_code)
    return response.json()

# %%
session_header = {'Authorization': 'Bearer {}'.format(access_token)}

# %% [markdown]
# ## Artist Albums
# Below I am taking the album ID of each of the top 5 pop artists' albums to disect.

# %%
weekend_album_id = '4yP0hdKOZPNshxUOjY0cZj'
taylor_album_id = '5H7ixXZfsNMGbIE5OBSpcb'
billie_album_id = '7aJuG4TFXa2hmE4z1yxc3n'
coldplay_album_id = '6ZG5lRT77aJ3btmArcykra'
drake_album_id = '40GMAhriYJRO1rsY4YdrZb'

# %%
weekend_album_response = api_call(ab_tracks_ep.format(weekend_album_id), session_header)
taylor_album_response = api_call(ab_tracks_ep.format(taylor_album_id), session_header)
billie_album_response = api_call(ab_tracks_ep.format(billie_album_id), session_header)
coldplay_album_response = api_call(ab_tracks_ep.format(coldplay_album_id), session_header)
drake_album_response = api_call(ab_tracks_ep.format(drake_album_id), session_header)
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
weekend_album_df = pd.DataFrame(weekend_album_response['items'])
taylor_album_df = pd.DataFrame(taylor_album_response['items'])
billie_album_df = pd.DataFrame(billie_album_response['items'])
coldplay_album_df = pd.DataFrame(coldplay_album_response['items'])
drake_album_df = pd.DataFrame(drake_album_response['items'])

# %% [markdown]
# ## Artist Tracks & Track Features
# Below I am taking the tracks from each album.

# %%
weekend_track_ids = ','.join(weekend_album_df['id'].to_list())
taylor_track_ids = ','.join(taylor_album_df['id'].to_list())
billie_track_ids = ','.join(billie_album_df['id'].to_list())
coldplay_track_ids = ','.join(coldplay_album_df['id'].to_list())
drake_track_ids = ','.join(drake_album_df['id'].to_list())

# %%
t_features_ep + '?ids={}'.format(weekend_track_ids)
# Out:
# 'https://api.spotify.com/v1/audio-features?ids=6b5P51m8xx2XA6U7sdNZ5E,2K9Ovn1o2bTGqbsABGC6m3,6kWxIqQDsKFYCJGbU4AjCX,4BGZF4oLbTL0pWm7C18pbv,3WlbeuhfRSqU7ylK2Ui5U7,1sOW4PuG5X3Ie3EXUhAopJ,6bnF93Rx87YqUBLSgjiMU8,3orEOtd8CPL8GFlpRpKuoE,0VjIjW4GlUZAMYd2vXMi3b,7szuecWAPwGoV1e5vGu8tl,5QO79kh1waicV47BqGRL3g,40U8d12pC5UHqmHwXjHjjl,2p8IUWQDrpjuFltbdgLOag,2BcnxwxBuar5wjCaLqm5N3'

# %%
weekend_track_features = api_call(t_features_ep + '?ids={}'.format(weekend_track_ids), 
                             session_header)
taylor_track_features = api_call(t_features_ep + '?ids={}'.format(taylor_track_ids), 
                             session_header)
billie_track_features = api_call(t_features_ep + '?ids={}'.format(billie_track_ids), 
                             session_header)
coldplay_track_features = api_call(t_features_ep + '?ids={}'.format(coldplay_track_ids), 
                             session_header)
drake_track_features = api_call(t_features_ep + '?ids={}'.format(drake_track_ids), 
                             session_header)
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
weekend_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(weekend_track_ids), 
                             session_header)
taylor_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(taylor_track_ids), 
                             session_header)
billie_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(billie_track_ids), 
                             session_header)
coldplay_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(coldplay_track_ids), 
                             session_header)
drake_track_info = api_call(tracks_ep + '?market=US&ids={}'.format(drake_track_ids), 
                             session_header)
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
weekend_features_df = pd.DataFrame(weekend_track_features['audio_features'])
taylor_features_df = pd.DataFrame(taylor_track_features['audio_features'])
billie_features_df = pd.DataFrame(billie_track_features['audio_features'])
coldplay_features_df = pd.DataFrame(coldplay_track_features['audio_features'])
drake_features_df = pd.DataFrame(drake_track_features['audio_features'])
#weekend_features_df.head()

# %%
weekend_tracks_df = pd.DataFrame(weekend_track_info['tracks'])
taylor_tracks_df = pd.DataFrame(taylor_track_info['tracks'])
billie_tracks_df = pd.DataFrame(billie_track_info['tracks'])
coldplay_tracks_df = pd.DataFrame(coldplay_track_info['tracks'])
drake_tracks_df = pd.DataFrame(drake_track_info['tracks'])
#weekend_tracks_df.head()

# %% [markdown]
# ## Artist Merged Data
# Below I am merging the data from both the artists' features and tracks. I am the sorting the information from most popular to least popular using the "popularity" key displaying only the head of the data.

# %%
weekend_merged = pd.merge(weekend_features_df, weekend_tracks_df, 
         how = 'inner', on = 'id').\
sort_values('popularity', ascending = False).head()
weekend_merged.head()
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 8          0.513   0.730    1    -5.940     1       0.0598       0.00143
# 10         0.679   0.825    0    -5.487     1       0.0309       0.02120
# 12         0.658   0.572    5    -6.099     0       0.0308       0.08110
# 6          0.537   0.746   10    -5.507     0       0.1500       0.02360
# 9          0.667   0.719    7    -5.371     0       0.0346       0.00280
#
#     instrumentalness  liveness  valence  ...              external_ids  \
# 8           0.000095    0.0897    0.334  ...  {'isrc': 'USUG11904206'}
# 10          0.000012    0.5430    0.644  ...  {'isrc': 'USUG12000658'}
# 12          0.006100    0.1210    0.144  ...  {'isrc': 'USUG12000586'}
# 6           0.000001    0.1560    0.252  ...  {'isrc': 'USUG11904007'}
# 9           0.000079    0.0736    0.718  ...  {'isrc': 'USUG12000657'}
#
#                                         external_urls  \
# 8   {'spotify': 'https://open.spotify.com/track/0V...
# 10  {'spotify': 'https://open.spotify.com/track/5Q...
# 12  {'spotify': 'https://open.spotify.com/track/2p...
# 6   {'spotify': 'https://open.spotify.com/track/6b...
# 9   {'spotify': 'https://open.spotify.com/track/7s...
#
#                                                  href is_local is_playable  \
# 8   https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...    False        True
# 10  https://api.spotify.com/v1/tracks/5QO79kh1waic...    False        True
# 12  https://api.spotify.com/v1/tracks/2p8IUWQDrpju...    False        True
# 6   https://api.spotify.com/v1/tracks/6bnF93Rx87Yq...    False        True
# 9   https://api.spotify.com/v1/tracks/7szuecWAPwGo...    False        True
#
#                name  popularity  track_number type_y  \
# 8   Blinding Lights          88             9  track
# 10  Save Your Tears          84            11  track
# 12      After Hours          80            13  track
# 6         Heartless          77             7  track
# 9      In Your Eyes          75            10  track
#
#                                    uri_y
# 8   spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# 10  spotify:track:5QO79kh1waicV47BqGRL3g
# 12  spotify:track:2p8IUWQDrpjuFltbdgLOag
# 6   spotify:track:6bnF93Rx87YqUBLSgjiMU8
# 9   spotify:track:7szuecWAPwGoV1e5vGu8tl
#
# [5 rows x 33 columns]

# %%
taylor_merged = pd.merge(taylor_features_df, taylor_tracks_df, 
         how = 'inner', on = 'id').\
sort_values('popularity', ascending = False).head()
taylor_merged.head()
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 8          0.626   0.428    2    -8.374     1       0.0261         0.607
# 0          0.504   0.386   11   -10.976     1       0.0308         0.502
# 2          0.596   0.563    0    -7.362     1       0.0269         0.137
# 3          0.541   0.366   11   -10.412     1       0.0748         0.560
# 17         0.784   0.391    9    -9.471     1       0.0633         0.608
#
#     instrumentalness  liveness  valence  ...              external_ids  \
# 8           0.000000    0.0921    0.487  ...  {'isrc': 'USUG12401036'}
# 0           0.000015    0.0961    0.281  ...  {'isrc': 'USUG12401028'}
# 2           0.000000    0.3020    0.481  ...  {'isrc': 'USUG12401030'}
# 3           0.000001    0.0946    0.168  ...  {'isrc': 'USUG12401031'}
# 17          0.000000    0.2520    0.150  ...  {'isrc': 'USUG12402541'}
#
#                                         external_urls  \
# 8   {'spotify': 'https://open.spotify.com/track/79...
# 0   {'spotify': 'https://open.spotify.com/track/6d...
# 2   {'spotify': 'https://open.spotify.com/track/7u...
# 3   {'spotify': 'https://open.spotify.com/track/1k...
# 17  {'spotify': 'https://open.spotify.com/track/1k...
#
#                                                  href is_local is_playable  \
# 8   https://api.spotify.com/v1/tracks/799KrpEbhZp0...    False        True
# 0   https://api.spotify.com/v1/tracks/6dODwocEuGzH...    False        True
# 2   https://api.spotify.com/v1/tracks/7uGYWMwRy24d...    False        True
# 3   https://api.spotify.com/v1/tracks/1kbEbBdEgQdQ...    False        True
# 17  https://api.spotify.com/v1/tracks/1kcwpPDQnqEq...    False        True
#
#                                     name  popularity  track_number type_y  \
# 8                         Guilty as Sin?          77             9  track
# 0          Fortnight (feat. Post Malone)          76             1  track
# 2   My Boy Only Breaks His Favorite Toys          76             3  track
# 3                               Down Bad          76             4  track
# 17                     imgonnagetyouback          76            18  track
#
#                                    uri_y
# 8   spotify:track:799KrpEbhZp0MHeiA8YK9P
# 0   spotify:track:6dODwocEuGzHAavXqTbwHv
# 2   spotify:track:7uGYWMwRy24dm7RUDDhUlD
# 3   spotify:track:1kbEbBdEgQdQeLXCJh28pJ
# 17  spotify:track:1kcwpPDQnqEqmezzXdJTCP
#
# [5 rows x 33 columns]

# %%
billie_merged = pd.merge(billie_features_df, billie_tracks_df, 
         how = 'inner', on = 'id').\
sort_values('popularity', ascending = False).head()
billie_merged.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 3         0.747   0.507    2   -10.171     1       0.0358        0.2000
# 4         0.467   0.247    6   -12.002     0       0.0431        0.6120
# 1         0.893   0.400   11    -7.981     0       0.0643        0.0452
# 2         0.700   0.425    7   -12.531     1       0.0529        0.1440
# 6         0.467   0.392    9    -9.355     1       0.0908        0.2000
#
#    instrumentalness  liveness  valence  ...              external_ids  \
# 3          0.060800    0.1170    0.438  ...  {'isrc': 'USUM72401994'}
# 4          0.000271    0.1700    0.126  ...  {'isrc': 'USUM72401993'}
# 1          0.082300    0.0632    0.945  ...  {'isrc': 'USUM72401991'}
# 2          0.879000    0.0830    0.521  ...  {'isrc': 'USUM72401988'}
# 6          0.017400    0.1060    0.313  ...  {'isrc': 'USUM72401990'}
#
#                                        external_urls  \
# 3  {'spotify': 'https://open.spotify.com/track/6d...
# 4  {'spotify': 'https://open.spotify.com/track/3Q...
# 1  {'spotify': 'https://open.spotify.com/track/62...
# 2  {'spotify': 'https://open.spotify.com/track/7B...
# 6  {'spotify': 'https://open.spotify.com/track/6f...
#
#                                                 href is_local is_playable  \
# 3  https://api.spotify.com/v1/tracks/6dOtVTDdiauQ...    False        True
# 4  https://api.spotify.com/v1/tracks/3QaPy1KgI7nu...    False        True
# 1  https://api.spotify.com/v1/tracks/629DixmZGHc7...    False        True
# 2  https://api.spotify.com/v1/tracks/7BRD7x5pt8Lq...    False        True
# 6  https://api.spotify.com/v1/tracks/6fPan2saHdFa...    False        True
#
#                  name  popularity  track_number type_y  \
# 3  BIRDS OF A FEATHER          98             4  track
# 4          WILDFLOWER          91             5  track
# 1               LUNCH          89             2  track
# 2             CHIHIRO          89             3  track
# 6   L’AMOUR DE MA VIE          84             7  track
#
#                                   uri_y
# 3  spotify:track:6dOtVTDdiauQNBQEDOtlAB
# 4  spotify:track:3QaPy1KgI7nu9FJEQUgn6h
# 1  spotify:track:629DixmZGHc7ILtEntuiWE
# 2  spotify:track:7BRD7x5pt8Lqa1eGYC4dzj
# 6  spotify:track:6fPan2saHdFaIHuTSatORv
#
# [5 rows x 33 columns]

# %%
coldplay_merged = pd.merge(coldplay_features_df, coldplay_tracks_df, 
         how = 'inner', on = 'id').\
sort_values('popularity', ascending = False).head()
coldplay_merged.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 4         0.429   0.661   11    -7.227     1       0.0281       0.00239
# 3         0.371   0.268    1   -10.506     1       0.0281       0.74800
# 5         0.565   0.546   11    -7.496     0       0.0314       0.18900
# 0         0.602   0.612    0    -8.409     1       0.0335       0.20600
# 1         0.396   0.803    4    -6.186     1       0.0487       0.03340
#
#    instrumentalness  liveness  valence  ...  \
# 4          0.000121    0.2340    0.285  ...
# 3          0.051700    0.1040    0.165  ...
# 5          0.001500    0.1700    0.195  ...
# 0          0.006070    0.1070    0.453  ...
# 1          0.000000    0.0688    0.286  ...
#
#                                        external_urls  \
# 4  {'spotify': 'https://open.spotify.com/track/3A...
# 3  {'spotify': 'https://open.spotify.com/track/7D...
# 5  {'spotify': 'https://open.spotify.com/track/0R...
# 0  {'spotify': 'https://open.spotify.com/track/2Q...
# 1  {'spotify': 'https://open.spotify.com/track/0q...
#
#                                                 href is_local is_playable  \
# 4  https://api.spotify.com/v1/tracks/3AJwUDP919kv...    False        True
# 3  https://api.spotify.com/v1/tracks/7D0RhFcb3Crf...    False        True
# 5  https://api.spotify.com/v1/tracks/0R8P9KfGJCDU...    False        True
# 0  https://api.spotify.com/v1/tracks/2QhURnm7mQDx...    False        True
# 1  https://api.spotify.com/v1/tracks/0qksx8mV28lz...    False        True
#
#           name popularity                                        preview_url  \
# 4       Yellow         89  https://p.scdn.co/mp3-preview/c0d9119dc69cae75...
# 3       Sparks         85  https://p.scdn.co/mp3-preview/4ffce9684e191005...
# 5      Trouble         72  https://p.scdn.co/mp3-preview/06ed55949d3f1676...
# 0  Don't Panic         70  https://p.scdn.co/mp3-preview/c7db43ba594e878a...
# 1       Shiver         65  https://p.scdn.co/mp3-preview/e5fbbfe9d4b7b84c...
#
#    track_number type_y                                 uri_y
# 4             5  track  spotify:track:3AJwUDP919kvQ9QcozQPxg
# 3             4  track  spotify:track:7D0RhFcb3CrfPuTJ0obrod
# 5             6  track  spotify:track:0R8P9KfGJCDULmlEoBagcO
# 0             1  track  spotify:track:2QhURnm7mQDxBb5jWkbDug
# 1             2  track  spotify:track:0qksx8mV28lztYIZ1om8ml
#
# [5 rows x 34 columns]

# %%
drake_merged = pd.merge(drake_features_df, drake_tracks_df, 
         how = 'inner', on = 'id').\
sort_values('popularity', ascending = False).head()
drake_merged.head()
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 11         0.792   0.625    1    -5.609     1       0.0536       0.00776
# 19         0.891   0.628    2    -7.863     1       0.0551       0.00258
# 16         0.699   0.255    4    -8.647     0       0.0303       0.40500
# 3          0.582   0.677    7    -7.081     1       0.1720       0.03120
# 15         0.794   0.653    7    -7.839     1       0.1040       0.04890
#
#     instrumentalness  liveness  valence  ...              external_ids  \
# 11          0.001800    0.3290    0.370  ...  {'isrc': 'USCM51600028'}
# 19          0.000190    0.0504    0.552  ...  {'isrc': 'USCM51500238'}
# 16          0.002420    0.0985    0.242  ...  {'isrc': 'USCM51600090'}
# 3           0.000007    0.1220    0.205  ...  {'isrc': 'USCM51600067'}
# 15          0.000049    0.1000    0.397  ...  {'isrc': 'USCM51600088'}
#
#                                         external_urls  \
# 11  {'spotify': 'https://open.spotify.com/track/1z...
# 19  {'spotify': 'https://open.spotify.com/track/0w...
# 16  {'spotify': 'https://open.spotify.com/track/3p...
# 3   {'spotify': 'https://open.spotify.com/track/3c...
# 15  {'spotify': 'https://open.spotify.com/track/3B...
#
#                                                  href is_local is_playable  \
# 11  https://api.spotify.com/v1/tracks/1zi7xx7UVEFk...    False        True
# 19  https://api.spotify.com/v1/tracks/0wwPcA6wtMf6...    False        True
# 16  https://api.spotify.com/v1/tracks/3ppVO2tyWRRz...    False        True
# 3   https://api.spotify.com/v1/tracks/3cjF2OFRmip8...    False        True
# 15  https://api.spotify.com/v1/tracks/3BtuIIrQlkuj...    False        True
#
#                       name  popularity  track_number type_y  \
# 11               One Dance          86            12  track
# 19           Hotline Bling          75            20  track
# 16  Summers Over Interlude          73            17  track
# 3             Feel No Ways          72             4  track
# 15                Too Good          72            16  track
#
#                                    uri_y
# 11  spotify:track:1zi7xx7UVEFkmKfv06H8x0
# 19  spotify:track:0wwPcA6wtMf6HUMpIRdeP7
# 16  spotify:track:3ppVO2tyWRRznNmONvt7Se
# 3   spotify:track:3cjF2OFRmip8spwZYQRKxP
# 15  spotify:track:3BtuIIrQlkujKPuWF2B85z
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Artist Compare
# Below I am adding the artist names to the dataframes and merging all the artist data to compare.

# %%
weekend_merged['artist'] = "The Weekend"
taylor_merged['artist'] = "Taylor Swift"
billie_merged['artist'] = "Billie Eilish"
coldplay_merged['artist'] = "Coldplay"
drake_merged['artist'] = "Drake"
weekend_merged.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type_x', 'id', 'uri_x', 'track_href', 'analysis_url', 'duration_ms_x',
#        'time_signature', 'album', 'artists', 'disc_number', 'duration_ms_y',
#        'explicit', 'external_ids', 'external_urls', 'href', 'is_local',
#        'is_playable', 'name', 'popularity', 'track_number', 'type_y', 'uri_y',
#        'artist'],
#       dtype='object')

# %%
artist_compare = pd.concat([weekend_merged.head(), taylor_merged.head(), billie_merged.head(), coldplay_merged.head(), drake_merged.head()], axis = 0).\
sort_values('popularity', ascending = False)
artist_compare.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 3         0.747   0.507    2   -10.171     1       0.0358       0.20000
# 4         0.467   0.247    6   -12.002     0       0.0431       0.61200
# 1         0.893   0.400   11    -7.981     0       0.0643       0.04520
# 4         0.429   0.661   11    -7.227     1       0.0281       0.00239
# 2         0.700   0.425    7   -12.531     1       0.0529       0.14400
#
#    instrumentalness  liveness  valence  ...  \
# 3          0.060800    0.1170    0.438  ...
# 4          0.000271    0.1700    0.126  ...
# 1          0.082300    0.0632    0.945  ...
# 4          0.000121    0.2340    0.285  ...
# 2          0.879000    0.0830    0.521  ...
#
#                                                 href is_local is_playable  \
# 3  https://api.spotify.com/v1/tracks/6dOtVTDdiauQ...    False        True
# 4  https://api.spotify.com/v1/tracks/3QaPy1KgI7nu...    False        True
# 1  https://api.spotify.com/v1/tracks/629DixmZGHc7...    False        True
# 4  https://api.spotify.com/v1/tracks/3AJwUDP919kv...    False        True
# 2  https://api.spotify.com/v1/tracks/7BRD7x5pt8Lq...    False        True
#
#                  name popularity track_number  type_y  \
# 3  BIRDS OF A FEATHER         98            4   track
# 4          WILDFLOWER         91            5   track
# 1               LUNCH         89            2   track
# 4              Yellow         89            5   track
# 2             CHIHIRO         89            3   track
#
#                                   uri_y         artist  \
# 3  spotify:track:6dOtVTDdiauQNBQEDOtlAB  Billie Eilish
# 4  spotify:track:3QaPy1KgI7nu9FJEQUgn6h  Billie Eilish
# 1  spotify:track:629DixmZGHc7ILtEntuiWE  Billie Eilish
# 4  spotify:track:3AJwUDP919kvQ9QcozQPxg       Coldplay
# 2  spotify:track:7BRD7x5pt8Lqa1eGYC4dzj  Billie Eilish
#
#                                          preview_url
# 3                                                NaN
# 4                                                NaN
# 1                                                NaN
# 4  https://p.scdn.co/mp3-preview/c0d9119dc69cae75...
# 2                                                NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Conclusion
# Overall, I do not think that the track number correlates to the popularity of the song. There were instances of the number 1 track being high on the popularity charts such as for Taylor Swift and Coldplay, but there were also examples where the number 1 was not even in the top 5 popularity for that album for all the other artists.
